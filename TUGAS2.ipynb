# %%
print("===           soal1         ===")
print("===s2===")
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7
s2_e = 5
s2_f = 0

s2 = (s2_a+s2_b+s2_c+s2_d+s2_e+s2_f)
print(s2)

print("===s1===")
s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0

hasils1 = (s1_a+s1_b+s1_c+s1_d+s1_e+s1_f)
print(hasils1)

print("===sma===")
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75

sma = (sma_a+sma_b+sma_c+sma_d+sma_e+f)
print(sma)

print("===smp===")
smp_a = 5
smp_b =6 
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15

smp = (smp_a+smp_b+smp_c+smp_d+smp_e+smp_f)
print(smp)

print("===sd===")
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1

hasilsd = (sd_a+sd_b+sd_c+sd_d+sd_e+sd_f)
print(hasilsd)

print("===tidak di ketahui===")
td_a = 2
td_b = 14
td_c =3 
td_d =10 
td_e = 0
td_f = 1

hasil = (td_a+td_b+td_c+td_d+td_e+td_f)
print(hasil)

print("============soal2============")
print("          ===S2===")
a = 17
b = 0.25
hasil = (a*b)
print("maka mutu dari S2 adalah : " +str(hasil))

print("          ===S1===")
a = 49
b = 0.20
hasil = (a*b)
print("maka mutu dari S1 adalah : " +str(hasil))

print("           ===SMA===")
a = 140
b = 0.15
hasil = (a*b)
print("maka mutu dari SMA adalah : " +str(hasil))

print("          ===SMP===")
a = 70
b = 0.10
hasil = (a*b)
print("maka mutu dari SMP adalah : " +str(hasil))

print("          ===Sd===")
a = 39
b = 0.05
hasil = (a*b)
print("maka mutu dari Sd adalah : " +str(hasil))

print("          ===tidak diketahui===")
a = 30
b = 0.03
hasil = (a*b)
print("maka mutu dari tidak ketahui adalah : " +str(hasil))

print("============soal3============")
print("=== usia 70 ===")
s2_a = 0
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 4
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 12
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 5
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 1
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 2
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 70 adalah : " +str(hasil1))

print("=== usia 60 ===")
s2_a = 1
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 12
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 17
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 6
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 8
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 14
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 60 adalah : " +str(hasil1))

print("=== usia 50 ===")
s2_a = 4
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 6
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 5
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 15
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 0
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 3
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 50 adalah : " +str(hasil1))

print("=== usia 40 ===")
s2_a = 7
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 13
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 20
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 9
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 19
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 10
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 40 adalah : " +str(hasil1))

print("=== usia 30 ===")
s2_a = 5
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 14
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 11
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 20
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 10
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 0
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 30 adalah : " +str(hasil1))

print("=== usia 20 ===")
s2_a = 0
s2_b = 0.25
hasil_s2 = (s2_a*s2_b)
print("maka mutu dari s2 adalah : " +str(hasil))
s1_a= 0
s1_b= 0.20
hasil_s1 = (s1_a*s1_b)
print("maka mutu dari s1 adalah : " +str(hasil))
sma_a= 75
sma_b= 0.15
hasil_sma = (sma_a*sma_b)
print("maka mutu dari sma adalah : " +str(hasil))
smp_a= 15
smp_b= 0.10
hasil_smp = (smp_a*smp_b)
print("maka mutu dari smp adalah : " +str(hasil))
sd_a= 1
sd_b= 0.05
hasil_sd = (sd_a*sd_b)
print("maka mutu dari sd adalah : " +str(hasil))
td_a= 1
td_b= 0.03
hasil_td = (td_a*td_b)
print("maka mutu dari tdk adalah : " +str(hasil))
hasil1 = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td) 
print("jumlah dmutu dari usia 20 adalah : " +str(hasil1))

print("============ soal 4 ============")

mins = [3.2099999999999995]
print("jadi index mutu yang paling kecil pada usia 70 = " +str(mins))

print("============ soal 4 ============")
# Out:
# ===           soal1         ===
# ===s2===
# 17
# ===s1===
# 49
# ===sma===
# 65.15
# ===smp===
# 70
# ===sd===
# 39
# ===tidak di ketahui===
# 30
# ============soal2============
#           ===S2===
# maka mutu dari S2 adalah : 4.25
#           ===S1===
# maka mutu dari S1 adalah : 9.8
#            ===SMA===
# maka mutu dari SMA adalah : 21.0
#           ===SMP===
# maka mutu dari SMP adalah : 7.0
#           ===Sd===
# maka mutu dari Sd adalah : 1.9500000000000002
#           ===tidak diketahui===
# maka mutu dari tidak ketahui adalah : 0.8999999999999999
# ============soal3============
# === usia 70 ===
# maka mutu dari s2 adalah : 0.8999999999999999
# maka mutu dari s1 adalah : 0.8999999999999999
# maka mutu dari sma adalah : 0.8999999999999999
# maka mutu dari smp adalah : 0.8999999999999999
# maka mutu dari sd adalah : 0.8999999999999999
# maka mutu dari tdk adalah : 0.8999999999999999
# jumlah dmutu dari usia 70 adalah : 3.2099999999999995
# === usia 60 ===
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['s2', 's1', 'sma','smp', 'sd', 'td']
total = [17, 49, 65.15, 70, 39, 30 ]
c =['red', 'orange','yelow','']
plt.title("jumlah di setiap pendidikan via bar")
plt.bar(pendidikan, total, )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
pendidikan = ['s2', 's1', 'sma','smp', 'sd', 'td']
total = [17, 49, 65.15, 70, 39, 30 ]

ax.pie(total,labels=pendidikan,autopct='%1.2f%%',)
plt.title("jumlah di setiap pendidikan via pie")

plt.show()

# %%
fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
usia = ['>70', '>60', '>50','>30', '', 'td']
jumlah = [17, 49, 65.15, 70, 39, 30 ]
c =['red', 'orange','yelow','']
plt.title("jumlah berdasarkan usia via bar")
plt.bar(pendidikan, total, )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
pendidikan = ['s2', 's1', 'sma','smp', 'sd', 'td']
total = [17, 49, 65.15, 70, 39, 30 ]

ax.pie(total,labels=pendidikan,autopct='%1.2f%%',)
plt.title("jumlah berdasarkan usia via bar")

plt.show()
