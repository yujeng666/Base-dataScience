# %%
print("=== SOAL 1 ===")
k10_a = 57
k10_b =  18
k10_c = 30
k10_d = 7
k10_e = 16
k10_f = 19
k10_g = 12

k10 = (k10_a + k10_b + k10_c + k10_d + k10_e + k10_f + k10_g)
print("jumlah siswa kelas 10 yang mengikuti eskul adalah : " +str(k10))

import matplotlib.pyplot as plt

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 5,  18, 30, 7, 16, 19, 12,]
c =['red', 'orange','yelow']
plt.title("jumlah siswa yang mengikuti eskul")
plt.bar(eskul, siswa,)
plt.show()
# Out:
# === SOAL 1 ===
# jumlah siswa kelas 10 yang mengikuti eskul adalah : 159

# %%
import matplotlib.pyplot as plt

# %%
print("                     === SOAL 2 ===")
print("=== PASKIBRA ===")
pas_a = 5		
pas_b =  21
pas_c = 6
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul paskibra adalah : " +str(paskibra))

print("===  PMR 	===")
pas_a = 18
pas_b = 4
pas_c = 12
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul pmr adalah : " +str(paskibra))

print("===  Pramuka		 ===")
pas_a = 30	
pas_b =	8 
pas_c = 24
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul pramuka adalah : " +str(paskibra))

print("=== Futsal	 ===")
pas_a = 7	
pas_b =	29  
pas_c =	15 
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul futsal adalah : " +str(paskibra))

print("=== Volly	===")
pas_a = 16	
pas_b =		10 
pas_c = 12
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul volly adalah : " +str(paskibra))

print("=== Kesenian ===")
pas_a =	19 		
pas_b =	18  
pas_c = 	4
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskul kesenian adalah : " +str(paskibra))

print("=== Rohis	 ===")
pas_a = 12		
pas_b = 	10
pas_c = 	7
paskibra = (pas_a + pas_b + pas_c )
print("jumlah siswa yang mengikuti eskulrohis adalah : " +str(paskibra))


fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 32,  34, 62, 51, 38, 41, 29,]
c =['red', 'orange','yelow','red']
plt.title("jumlah siswa yang mengikuti eskul")
plt.bar(eskul, siswa,  )
plt.show()
# Out:
#                      === SOAL 2 ===
# === PASKIBRA ===
# jumlah siswa yang mengikuti eskul paskibra adalah : 32
# ===  PMR 	===
# jumlah siswa yang mengikuti eskul pmr adalah : 34
# ===  Pramuka		 ===
# jumlah siswa yang mengikuti eskul pramuka adalah : 62
# === Futsal	 ===
# jumlah siswa yang mengikuti eskul futsal adalah : 51
# === Volly	===
# jumlah siswa yang mengikuti eskul volly adalah : 38
# === Kesenian ===
# jumlah siswa yang mengikuti eskul kesenian adalah : 41
# === Rohis	 ===
# jumlah siswa yang mengikuti eskulrohis adalah : 29

# %%
print("                     === SOAL 3 ===")
a = 7		
b = 29		
c =	15
d =16
e =10
f = 12
hasil1 = (a + b + c + d + e + f)
print("jumlah siswa yang mengikuti eskul olahraga adalah  adalah : " +str(hasil1))

a = 107				
b = 100
c = 80
hasil2 = (a + b + c )
print("jumlah siswa yang mengikuti eskul  adalah : " +str(hasil2))
hasil = (hasil2-hasil1)
print("jumlah siswa yang mengikuti eskul  adalah : " +str(hasil))
a = 17		
b = 8
c = 20
hasil3 = (a + b + c )
print("jumlah siswa yang tidak mengikuti eskul  adalah : " +str(hasil3))

a = 89
b = 198
c = 45
hasil =(a+b+c)
print("presentase dari kelas 10  adalah : " +str(hasil))

hasil1 = (a * 100 / hasil  )
hasil2 = (b * 100 / hasil  )
hasil3 = (c * 100 / hasil  )
print("presentase dari kelas 10  adalah : " +str(hasil1))
print("presentase dari kelas 11  adalah : " +str(hasil2))
print("presentase dari kelas 10  adalah : " +str(hasil3))

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['eskul olahraga',  'mengikuti','tidak mengikuti']
siswa = [ 89,  198, 45]
c =['red', 'orange','yelow','red']
plt.title("jumlah siswa yang mengikuti eskul di KELAS 10")
plt.bar(eskul, siswa,  )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
eskul = ['eskul olahraga',  'mengikuti','tidak mengikuti']
siswa = [ 89,  198, 45]

ax.pie(siswa,labels=eskul,autopct='%1.2f%%',)
plt.title("jumlah siswa yang mengikuti eskul di KELAS 10")
plt.show()
# Out:
#                      === SOAL 3 ===
# jumlah siswa yang mengikuti eskul olahraga adalah  adalah : 89
# jumlah siswa yang mengikuti eskul  adalah : 287
# jumlah siswa yang mengikuti eskul  adalah : 198
# jumlah siswa yang tidak mengikuti eskul  adalah : 45
# presentase dari kelas 10  adalah : 332
# presentase dari kelas 10  adalah : 26.80722891566265
# presentase dari kelas 11  adalah : 59.63855421686747
# presentase dari kelas 10  adalah : 13.55421686746988

# %%
print("                     === SOAL 4 ===")
a = 17		
b = 8
c = 20
hasil = (a + b + c )
print("jumlah siswa yang tidak mengikuti eskul  adalah : " +str(hasil))

a = 17		
b = 8
c = 20
d = 45
hasil1 = (a * 100 / d  )
hasil2 = (b * 100 / d  )
hasil3 = (c * 100 / d  )
print("presentase dari kelas 10  adalah : " +str(hasil1))
print("presentase dari kelas 11  adalah : " +str(hasil2))
print("presentase dari kelas 10  adalah : " +str(hasil3))
hasil = (hasil1 + hasil2 + hasil3)
print("total presentase : "+ str(hasil))

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
tingkatan = ['KLS 10', 'KLS 11', 'KLS 12']
jumlah = [17, 8, 20 ]

ax.pie(jumlah,labels=tingkatan,autopct='%1.2f%%',)
plt.title("jumlah di setiap pendidikan via pie")

plt.show()
# Out:
#                      === SOAL 4 ===
# jumlah siswa yang tidak mengikuti eskul  adalah : 45
# presentase dari kelas 10  adalah : 37.77777777777778
# presentase dari kelas 11  adalah : 17.77777777777778
# presentase dari kelas 10  adalah : 44.44444444444444
# total presentase : 100.0

# %%
print("                     === SOAL 5 ===")
print("=====KELAS 10=====")
k10_a = 5
k10_b = 18
k10_c = 30
k10_d = 7
k10_e = 16
k10_f = 19
k10_g = 12

k10 = (k10_a + k10_b + k10_c + k10_d + k10_e + k10_f + k10_g)
print("jumlah siswa kelas 10 yang mengikuti eskul adalah : " +str(k10))


fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 32,  34, 62, 51, 38, 41, 29,]
c =['red', 'orange','yelow','red']
plt.title("jumlah siswa yang mengikuti eskul di KELAS 10")
plt.bar(eskul, siswa,  )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 32,  34, 62, 51, 38, 41, 29,]

ax.pie(siswa,labels=eskul,autopct='%1.2f%%',)
plt.title("jumlah siswa yang mengikuti eskul di KELAS 10")
plt.show()

print("=====KELAS 11=====")
k11_a = 21
k11_b =  4
k11_c = 8
k11_d = 29
k11_e = 10
k11_f = 18
k11_g = 10

k11 = (k11_a + k11_b + k11_c + k11_d + k11_e + k11_f + k11_g)
print("jumlah siswa kelas 10 yang mengikuti eskul adalah : " +str(k11))


fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 21, 4, 8, 29, 10, 18, 10,]
c =['red', 'orange','yelow','red']
plt.title("jumlah siswa yang mengikuti eskul di KELAS 11")
plt.bar(eskul, siswa,  )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa =  [ 21, 4, 8, 29, 10, 18, 10,]

ax.pie(siswa,labels=eskul,autopct='%1.2f%%',)
plt.title("jumlah siswa yang mengikuti eskul di KELAS 11")
plt.show()

print("=====KELAS 12=====")
k12_a = 6
k12_b =  12
k12_c = 24
k12_d = 15
k12_e = 12
k12_f = 4
k12_g = 7

k12 = (k12_a + k12_b + k12_c + k12_d + k12_e + k12_f + k12_g)
print("jumlah siswa kelas 10 yang mengikuti eskul adalah : " +str(k12))


fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 6, 12, 24, 15, 12, 4, 7]
c =['red', 'orange','yelow','red']
plt.title("jumlah siswa yang mengikuti eskul di KELAS 12")
plt.bar(eskul, siswa,  )
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
eskul = ['paskibra',  'PMR','Pramuka', 'Futsal', 'Volly','Kesenian','Rohis']
siswa = [ 6, 12, 24, 15, 12, 4, 7]

ax.pie(siswa,labels=eskul,autopct='%1.2f%%',)
plt.title("jumlah siswa yang mengikuti eskul di KELAS 12")
plt.show()
# Out:
#                      === SOAL 5 ===
# =====KELAS 10=====
# jumlah siswa kelas 10 yang mengikuti eskul adalah : 107
# =====KELAS 11=====
# jumlah siswa kelas 10 yang mengikuti eskul adalah : 100
# =====KELAS 12=====
# jumlah siswa kelas 10 yang mengikuti eskul adalah : 80
