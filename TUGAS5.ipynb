# %%
print("=====   SOAL 1   =====")
print("=====   A-Xis  =====")
a = 20
b = 300000
c = 75000

hasil = (a * b ) + (a*c)
print("maka pengeluaran  perusahaan A-Xis adalah Rp." +str(hasil))

print("=====   B-Log =====")
a = 14
b = 360000
c = 75000

hasil = (a * b ) + (a*c)
print("maka pengeluaran  perusahaan B-Log adalah Rp." +str(hasil))

print("=====   C-in  =====")
a = 28
b = 475000
c = 75000

hasil = (a * b ) + (a*c)
print("maka pengeluaran perusahaan C-in adalah Rp." +str(hasil))

print("=====   D-Namic  =====")
a = 42
b = 580000
c = 75000

hasil = (a * b ) + (a*c)
print("maka pengeluaran  perusahaan D-Namic adalah Rp." +str(hasil))

print("=====   E-psilon  =====")
a = 18
b = 400000
c = 75000

hasil = (a * b ) + (a*c)
print("maka pengeluaran  perusahaan E-psilon adalah Rp." +str(hasil))
# Out:
# =====   SOAL 1   =====
# =====   A-Xis  =====
# maka pengeluaran  perusahaan A-Xis adalah Rp.7500000
# =====   B-Log =====
# maka pengeluaran  perusahaan B-Log adalah Rp.6090000
# =====   C-in  =====
# maka pengeluaran perusahaan C-in adalah Rp.15400000
# =====   D-Namic  =====
# maka pengeluaran  perusahaan D-Namic adalah Rp.27510000
# =====   E-psilon  =====
# maka pengeluaran  perusahaan E-psilon adalah Rp.8550000

# %%
print("=====   SOAL 2   =====")
print("=====   A-Xis  =====")
pajak = 0.03 

utang1 = 0.08
utang2 = 0.04
utang3 = 0.12
utang4 = 0.11
utang5 = 0.03

laba1 = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

hasil = (pajak * laba1) + (utang1 * 280000000)
print ("Total pajak dan utantg dari perusahaan A-Xis adalah Rp." +str (hasil))

print("=====  B-Log  =====")
hasil = (pajak * laba2) + (utang2 * 310000000)
print ("Total pajak dan utantg dari perusahaan B-Log adalah Rp." +str (hasil))

print("=====   C-in  =====")
hasil = (pajak * laba3) + (utang3 * 420000000)
print ("Total pajak dan utantg dari perusahaan C-in adalah Rp." +str (hasil))

print("=====   D-Namic  =====")
hasil = (pajak * laba4) + (utang4 * 550000000)
print ("Total pajak dan utantg dari perusahaan D-Namic adalah Rp." +str (hasil))

print("=====   E-psilon  =====")
hasil = (pajak * laba5) + (utang5 *340000000)
print ("Total pajak dan utantg dari perusahaan E-psilon adalah Rp." +str (hasil))

import matplotlib.pyplot as plt

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
no = [23375000,13330000,51660000,62045000, 11010000]
plt.title("Data pajak dan utang perusahaan")
plt.bar(perusahaan, no,)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
no = [23375000,13330000,51660000,62045000, 11010000]

ax.pie(no,labels=perusahaan,autopct='%1.2f%%',)
plt.title("Data pajak dan utang perusahaan")
plt.show()
# Out:
# =====   SOAL 2   =====
# =====   A-Xis  =====
# Total pajak dan utantg dari perusahaan A-Xis adalah Rp.23375000.0
# =====  B-Log  =====
# Total pajak dan utantg dari perusahaan B-Log adalah Rp.13330000.0
# =====   C-in  =====
# Total pajak dan utantg dari perusahaan C-in adalah Rp.51660000.0
# =====   D-Namic  =====
# Total pajak dan utantg dari perusahaan D-Namic adalah Rp.62045000.0
# =====   E-psilon  =====
# Total pajak dan utantg dari perusahaan E-psilon adalah Rp.11010000.0

# %%
print("=====   SOAL 3   =====")
csr1 = 0.025
csr2 = 0.035
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000

print("=====   A-Xis  =====")
hasil= (aset1 * csr1 )
print("Csr dari perusahaan A-Xis adalah Rp." +str (hasil))

print("=====   B-Log  =====")
hasil= (aset2 * csr2 )
print("Csr dari perusahaan B-Log adalah Rp." +str (hasil))

print("=====  C-in  =====")
hasil= (aset3 * csr2 )
print("Csr dari perusahaan C-in  adalah Rp." +str (hasil))

print("=====  D-Namic  =====")
hasil= (aset4 * csr2 )
print("Csr dari perusahaan D-Namic adalah Rp." +str (hasil))

print("=====   E-psilon  =====")
hasil= (aset5 * csr2 )
print("Csr dari perusahaan E-psilon adalah Rp." +str (hasil))

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
no = [7000000,10850000.000000002,14700000.000000002,19250000,11900000.000000002]
plt.title("Data pengeluaran pajak dan gaji perusahaan")
plt.bar(perusahaan, no,)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
no = [7000000,10850000.000000002,14700000.000000002,19250000,11900000.000000002]

ax.pie(no,labels=perusahaan,autopct='%1.2f%%',)
plt.title("Data pengeluaran pajak dan gaji perusahaan")
plt.show()
# Out:
# =====   SOAL 3   =====
# =====   A-Xis  =====
# Csr dari perusahaan A-Xis adalah Rp.7000000.0
# =====   B-Log  =====
# Csr dari perusahaan B-Log adalah Rp.10850000.000000002
# =====  C-in  =====
# Csr dari perusahaan C-in  adalah Rp.14700000.000000002
# =====  D-Namic  =====
# Csr dari perusahaan D-Namic adalah Rp.19250000.0
# =====   E-psilon  =====
# Csr dari perusahaan E-psilon adalah Rp.11900000.000000002

# %%
print("=====   SOAL 4   =====")
print("=====   A-Xis  =====")
laba = 32500000
tahun = 12
hasil1 = (laba * tahun)
print("maka laba pertahun nya adalah Rp." +str(hasil1))

print("=====   B-Log  =====")
laba = 31000000
hasil2 = (laba * tahun)
print("maka laba pertahun nya adalah Rp." +str(hasil2))

print("=====   C-in  =====")
laba = 42000000
hasil3 = (laba * tahun)
print("maka laba pertahun nya adalah Rp." +str(hasil3))

print("=====   D-Namic  =====")
laba = 51500000
hasil4 = (laba * tahun)
print("maka laba pertahun nya adalah Rp." +str(hasil4))

print("=====  E-psilon  =====")
laba = 27000000
hasil5 = (laba * tahun)
print("maka laba pertahun nya adalah Rp." +str(hasil5))

hasil =(hasil1 + hasil2 + hasil3 + hasil4 +hasil5)
print("maka total laba seluruh perusahaan adalah : Rp." +str (hasil))
# Out:
# =====   SOAL 4   =====
# =====   A-Xis  =====
# maka laba pertahun nya adalah Rp.390000000
# =====   B-Log  =====
# maka laba pertahun nya adalah Rp.372000000
# =====   C-in  =====
# maka laba pertahun nya adalah Rp.504000000
# =====   D-Namic  =====
# maka laba pertahun nya adalah Rp.618000000
# =====  E-psilon  =====
# maka laba pertahun nya adalah Rp.324000000
# maka total laba seluruh perusahaan adalah : Rp.2208000000

# %%
print("=====   SOAL 5   =====")

laba1 = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

#gaji dan suransi
gaji1 = 7500000
gaji2 = 6090000
gaji3 = 15400000
gaji4 = 27510000
gaji5 = 8550000

aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000

pu1 = 23375000
pu2 = 13330000
pu3 = 51660000
pu4 = 62045000
pu5 = 11010000

csra= 0.025
csrb= 0.035


print("=====   A-Xis  =====")

hasil1= (laba1 * 12) - csra * aset1 - (gaji1 * 12) - pu1
print("maka pendapatan bersih perusahaan A-Xis adalah : Rp." +str (hasil1))

print("=====   B-Log  =====")

hasil2= (laba2 * 12) - csrb * aset2 - (gaji2 * 12) - pu2
print("maka pendapatan bersih perusahaan B-Log adalah : Rp." +str (hasil2))

print("=====   C-in  =====")

hasil3= (laba3 * 12) - csrb * aset3 - (gaji3 * 12) - pu3
print("maka pendapatan bersih perusahaan C-in adalah : Rp." +str (hasil3))

print("=====   D-Namic  =====")

hasil4= (laba4 * 12) - csrb * aset4 - (gaji4 * 12) - pu4
print("maka pendapatan bersih perusahaan D-Namic adalah : Rp." +str (hasil4))

print("=====   E-psilon  =====")

hasil5= (laba5 * 12) - csrb * aset5 - (gaji5 * 12) - pu5
print("maka pendapatan bersih perusahaan E-psilon adalah : Rp." +str (hasil5))

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
pendapatan = [269625000,274740000,252840000,206585000,198490000]
plt.title("Data pengeluaran pajak dan gaji perusahaan")
plt.bar(perusahaan, pendapatan,)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log','C-in', 'D-Namic', ' E-psilon',]
pendapatan = [269625000,274740000,252840000,206585000,198490000]

ax.pie(pendapatan,labels=perusahaan,autopct='%1.2f%%',)
plt.title("Data pengeluaran pajak dan gaji perusahaan")
plt.show()
# Out:
# =====   SOAL 5   =====
# =====   A-Xis  =====
# maka pendapatan bersih perusahaan A-Xis adalah : Rp.269625000.0
# =====   B-Log  =====
# maka pendapatan bersih perusahaan B-Log adalah : Rp.274740000.0
# =====   C-in  =====
# maka pendapatan bersih perusahaan C-in adalah : Rp.252840000.0
# =====   D-Namic  =====
# maka pendapatan bersih perusahaan D-Namic adalah : Rp.206585000.0
# =====   E-psilon  =====
# maka pendapatan bersih perusahaan E-psilon adalah : Rp.198490000.0
