# %%
#Tugas
beras = 11400 #/kilo
minyak = 12700 #/liter
ayam = 3400 #pergram
telur = 21800 #/kilo
popok = 27000 #/pcs
sabun_cuci =1800 #/gam
buah_anggur =3800 #/gram
roti_tawar =8500 #/gram
tissu =6400 #/pcs
mie_instan =2200 #/pcs

print("===belanjaan tia===")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
buah_anggur_tia = 4
roti_tawar_tia = 2
mie_instan_tia = 12
tb_tia = (beras_tia * beras) + (ayam_tia * (ayam * 10)) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
diskon = 85
tb_diskon_tia = (tb_tia / 100 ) * 85
print("maka total belanjaan tia Rp." + str(tb_tia))
print("maka total belanjaan tia setleah mendapatkan diskon Rp." + str(tb_diskon_tia))

print("===belanjaan hana===")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_cuci_hana = 3
buah_anggur_hana = 8
roti_tawar_hana = 3
tissu_hana = 2
mie_instan_hana = 20
tb_hana = (minyak_hana * minyak) + (ayam_hana * ayam) + (telur_hana * telur) + (sabun_cuci_hana * sabun_cuci) + (buah_anggur_hana * buah_anggur) + (roti_tawar_hana * roti_tawar) + (tissu_hana * tissu) + (mie_instan_hana * mie_instan)
diskon = 90
tb_diskon_hana = (tb_hana / 100 ) * 90
print("maka total belanjaan hana Rp." + str(tb_hana))
print("maka total belanjaan hana setleah mendapatkan diskon Rp." + str(tb_diskon_hana))

print("===belanjaan widia===")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_anggur_widia = 5
tissu_widia = 3
mie_instan_widia = 16
tb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (buah_anggur_widia * buah_anggur) + (tissu_widia * tissu) + (mie_instan_widia * mie_instan)
print("maka total belanjaan widia Rp." + str(tb_widia))

print("===belanjaan romi===")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_cuci_romi = 8
mie_instan_romi = 8
tb_romi =  (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_cuci_romi * sabun_cuci) + (mie_instan_romi * mie_instan)
diskon = 85
tb_diskon_romi = (tb_romi / 100 ) * 85
print("maka total belanjaan romi Rp." + str(tb_romi))
print("maka total belanjaan romi setleah mendapatkan diskon Rp." + str(tb_diskon_romi))

print("===belanjaan samsul===")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_anggur_samsul = 7
tissu_samsul = 5
mie_instan_samsul = 10
diskon = 75
tb_diskon_samsul = (tb_samsul / 100 ) * 85
tb_samsul= (ayam_samsul * (ayam * 10)) + (telur_samsul * telur) + (popok_samsul * popok) + (buah_anggur_samsul * buah_anggur) + (tissu_samsul * tissu) + (mie_instan_samsul * mie_instan)
print("maka total belanjaan samsul Rp." + str(tb_samsul))
print("maka total belanjaan samsul setleah mendapatkan diskon Rp." + str(tb_diskon_samsul))

print("===belanjaan dimas===")
ayam_dimas = 5
popok_dimas = 5
sabun_cuci_dimas = 4
buah_anggur_dimas = 3
roti_tawar_dimas = 5
mie_instan_dimas = 6
diskon = 75
tb_diskon_dimas = (tb_dimas / 100 ) * 75
tb_dimas = (ayam_dimas * (ayam * 10)) +(popok_dimas * popok) +  (sabun_cuci_dimas * sabun_cuci) + (buah_anggur_dimas * buah_anggur) +  (roti_tawar_dimas * roti_tawar) + (mie_instan_dimas* mie_instan)
print("maka total belanjaan dimas Rp." + str(tb_dimas))
print("maka total belanjaan dimas setleah mendapatkan diskon Rp." + str(tb_diskon_dimas))

print(max(tb_diskon_tia, tb_diskon_hana, tb_widia, tb_diskon_romi, tb_diskon_samsul, tb_diskon_dimas))
print("total belanjaan yang paling banyak adalah dimas Rp." + str(tb_dimas))

print("yang mendapatkan diskon 10% adalah hana")

maxz = [284475]
print("total belanjaan yang paling banyak adalah dimas Rp." +str(maxz))
tenpersen = {"hana" : "Rp.173880"}
print("yang mendapatkan diskon 10% adalah " +str(tenpersen))
# Out:
# ===belanjaan tia===
# maka total belanjaan tia Rp.246600
# maka total belanjaan tia setleah mendapatkan diskon Rp.209610.0
# ===belanjaan hana===
# maka total belanjaan hana Rp.193200.0
# maka total belanjaan hana setleah mendapatkan diskon Rp.173880.0
# ===belanjaan widia===
# maka total belanjaan widia Rp.119300
# ===belanjaan romi===
# maka total belanjaan romi Rp.221700
# maka total belanjaan romi setleah mendapatkan diskon Rp.188445.0
# ===belanjaan samsul===
# maka total belanjaan samsul Rp.323800
# maka total belanjaan samsul setleah mendapatkan diskon Rp.275230.0
# ===belanjaan dimas===
# maka total belanjaan dimas Rp.379300
# maka total belanjaan dimas setleah mendapatkan diskon Rp.284475.0
# 284475.0
# total belanjaan yang paling banyak adalah dimas Rp.379300
# yang mendapatkan diskon 10% adalah hana
# total belanjaan yang paling banyak adalah dimas Rp.[284475]
# yang mendapatkan diskon 10% adalah {'hana': 'Rp.173880'}

# %%
import matplotlib.pyplot as plt

# %%
fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
nama = ['tia', 'hana', 'widia','romi', 'samsul', 'dimas']
total_dengan_diskon = [246600, 193200, 119300, 221700, 323800, 379300 ]
c =['yellow', 'red','black']
plt.title("total belanjaan masing masing ")
plt.bar(nama, total_dengan_diskon, color = c)
plt.show()


fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
nama = ['tia', 'hana', 'widia','romi', 'samsul', 'dimas']
total_dengan_diskon = [209610, 173880, 119300, 188445, 275230, 284475 ]
c =['yellow', 'red','black']
plt.title("total belanjaan masing masing setelah mendapatkan diskon")
plt.bar(nama, total_dengan_diskon, color = c)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
nama = ['tia', 'hana', 'widia','romi', 'samsul', 'dimas']
total_belanjaan = [246600, 193200, 119300, 221700, 323800, 379300 ]

ax.pie(total_belanjaan,labels=nama,autopct='%1.2f%%',)
plt.title("total belanjaan masing masing")

plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
nama = ['tia', 'hana', 'widia','romi', 'samsul', 'dimas']
total_dengan_diskon = [209610, 173880, 119300, 188445, 275230, 284475 ]

ax.pie(total_dengan_diskon,labels=nama,autopct='%1.2f%%',)
plt.title("total belanjaan masing masing setelah mendapatkan diskon")

plt.show()
